# %% [markdown]
# ## File download to local drive

# %%
# %env drop=/home/ubuntu/000dropbox
#%env drop=opt/cloud-veg-et/model_outputs

import boto3
from boto3 import client
def bo_get_bucket_list(bucket_name, prefix):

    s3_conn   = client('s3')  # type: BaseClient  ## again assumes boto.cfg setup, assume AWS S3
    s3_result =  s3_conn.list_objects_v2(Bucket=bucket_name, Prefix=prefix, Delimiter = "/")

    if 'Contents' not in s3_result:
        #print(s3_result)
        return []

    file_list = []
    for key in s3_result['Contents']:
        file_list.append(key['Key'])
    print(f"List count = {len(file_list)}")

    while s3_result['IsTruncated']:
        continuation_key = s3_result['NextContinuationToken']
        s3_result = s3_conn.list_objects_v2(Bucket=bucket_name, Prefix=prefix, Delimiter="/", ContinuationToken=continuation_key)
        for key in s3_result['Contents']:
            file_list.append(key['Key'])
        print(f"List count = {len(file_list)}")
    return file_list

buck = 'ga-et-data'
pre = 'gabe_outputs/model_outputs/'

file_list = bo_get_bucket_list(buck, pre)

print(file_list[1])
# Out:
# env: drop=/home/ubuntu/000dropbox
# List count = 1000
# List count = 2000
# List count = 3000
# List count = 4000
# List count = 5000
# List count = 6000
# List count = 7000
# List count = 8000
# List count = 9000
# List count = 10000
# List count = 11000
# List count = 12000
# List count = 12009
# gabe_outputs/model_outputs/dd_201310.tif

# %%
#Filter list for needed files
filter='2013274'
filtered_list = []
for file in file_list:
    if (filter in file):
        # print(file)
        filtered_list.append(file)

# "copy" all needed file names in txt file        
target = open('export_files.txt', 'w')
for file in filtered_list:
    print(file)
    target.write(file+'\n')
target.close()
# Out:
# gabe_outputs/model_outputs/dd_2013274.tif
# gabe_outputs/model_outputs/etasw5_2013274.tif
# gabe_outputs/model_outputs/etasw_2013274.tif
# gabe_outputs/model_outputs/rain_2013274.tif
# gabe_outputs/model_outputs/snowmelt_2013274.tif
# gabe_outputs/model_outputs/snwpk_2013274.tif
# gabe_outputs/model_outputs/srf_2013274.tif
# gabe_outputs/model_outputs/swe_2013274.tif
# gabe_outputs/model_outputs/swf_2013274.tif
# gabe_outputs/model_outputs/swi_2013274.tif

# %%
! cat -n export_files.txt
# Out:
#      1	gabe_outputs/model_outputs/dd_2013274.tif
#      2	gabe_outputs/model_outputs/etasw5_2013274.tif
#      3	gabe_outputs/model_outputs/etasw_2013274.tif
#      4	gabe_outputs/model_outputs/rain_2013274.tif
#      5	gabe_outputs/model_outputs/snowmelt_2013274.tif
#      6	gabe_outputs/model_outputs/snwpk_2013274.tif
#      7	gabe_outputs/model_outputs/srf_2013274.tif
#      8	gabe_outputs/model_outputs/swe_2013274.tif
#      9	gabe_outputs/model_outputs/swf_2013274.tif
#     10	gabe_outputs/model_outputs/swi_2013274.tif

# %%
# %%bash
#
# for s3obj in `cat export_files.txt`; do
#     echo $s3obj;
#     aws s3 cp s3://ga-et-data/$s3obj $drop/
# done
# Out:
# gabe_outputs/model_outputs/dd_2013274.tif
# download: s3://ga-et-data/gabe_outputs/model_outputs/dd_2013274.tif to ../../../ubuntu/000dropbox/dd_2013274.tif
# gabe_outputs/model_outputs/etasw5_2013274.tif
# download: s3://ga-et-data/gabe_outputs/model_outputs/etasw5_2013274.tif to ../../../ubuntu/000dropbox/etasw5_2013274.tif
# gabe_outputs/model_outputs/etasw_2013274.tif
# download: s3://ga-et-data/gabe_outputs/model_outputs/etasw_2013274.tif to ../../../ubuntu/000dropbox/etasw_2013274.tif
# gabe_outputs/model_outputs/rain_2013274.tif
# download: s3://ga-et-data/gabe_outputs/model_outputs/rain_2013274.tif to ../../../ubuntu/000dropbox/rain_2013274.tif
# gabe_outputs/model_outputs/snowmelt_2013274.tif
# download: s3://ga-et-data/gabe_outputs/model_outputs/snowmelt_2013274.tif to ../../../ubuntu/000dropbox/snowmelt_2013274.tif
# gabe_outputs/model_outputs/snwpk_2013274.tif
# download: s3://ga-et-data/gabe_outputs/model_outputs/snwpk_2013274.tif to ../../../ubuntu/000dropbox/snwpk_2013274.tif
# gabe_outputs/model_outputs/srf_2013274.tif
# download: s3://ga-et-data/gabe_outputs/model_outputs/srf_2013274.tif to ../../../ubuntu/000dropbox/srf_2013274.tif
# gabe_outputs/model_outputs/swe_2013274.tif
# download: s3://ga-et-data/gabe_outputs/model_outputs/swe_2013274.tif to ../../../ubuntu/000dropbox/swe_2013274.tif
# gabe_outputs/model_outputs/swf_2013274.tif
# download: s3://ga-et-data/gabe_outputs/model_outputs/swf_2013274.tif to ../../../ubuntu/000dropbox/swf_2013274.tif
# gabe_outputs/model_outputs/swi_2013274.tif
# download: s3://ga-et-data/gabe_outputs/model_outputs/swi_2013274.tif to ../../../ubuntu/000dropbox/swi_2013274.tif

# %%
! ls ~ubuntu/000dropbox
# Out:
# dd_2013274.tif	    etasw_2013276.tif	  snwpk_2013275.tif  swf_2013274.tif
# dd_2013275.tif	    rain_2013274.tif	  snwpk_2013276.tif  swf_2013275.tif
# dd_2013276.tif	    rain_2013275.tif	  srf_2013274.tif    swf_2013276.tif
# etasw5_2013274.tif  rain_2013276.tif	  srf_2013275.tif    swi_2013274.tif
# etasw5_2013275.tif  snowmelt_2013274.tif  srf_2013276.tif    swi_2013275.tif
# etasw5_2013276.tif  snowmelt_2013275.tif  swe_2013274.tif    swi_2013276.tif
# etasw_2013274.tif   snowmelt_2013276.tif  swe_2013275.tif
# etasw_2013275.tif   snwpk_2013274.tif	  swe_2013276.tif

# %%
# ! ls -lR $drop
