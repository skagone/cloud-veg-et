# %% [markdown]
# # Collaborate

# %% [markdown]
# # 5/28/2020 preview

# %%
from IPython.display import SVG, display

# %%
SVG('api.svg')

# %%
SVG('veget.svg')

# %% [markdown]
# ---
# ---
#
# # 5/27/2020

# %% [markdown]
# - demo nano
#
# ## today's ideas
#
# ### this approach was gleaned from Hitchikers guide to python BOOK
#
# - show howdoi code as a good example
# - show plagerize howdoi for parameters in command_line_runner
# - show readme.md rendered in a notebook
# - debugger ?
# - graph the code
# - logging
# - git ssh keys
#
# - run the api_veget - terminal

# %%
# Render readme in a notebook cool
from IPython.display import display, Markdown

with open('Readme.md', 'r') as fh:
    content = fh.read()

display(Markdown(content))
# Out:
# # API
#
# ## The main function caller

# %%
def render_md(filename):
    with open(filename, 'r') as fh:
        content = fh.read()
    display(Markdown(content))

# %%
render_md('/home/jupyter-kagone/train/howdoi/README.rst')
# Out:
# howdoi
# ...
#
# .. image:: http://imgs.xkcd.com/comics/tar.png
#         :target: https://xkcd.com/1168/
#
# instant coding answers via the command line
# -------------------------------------------
#
# .. image:: https://secure.travis-ci.org/gleitz/howdoi.png?branch=master
#         :target: https://travis-ci.org/gleitz/howdoi
#
# .. image:: https://pepy.tech/badge/howdoi
#         :target: https://pepy.tech/project/howdoi
#
# Are you a hack programmer? Do you find yourself constantly Googling for
# how to do basic programming tasks?
#
# Suppose you want to know how to format a date in bash. Why open your browser
# and read through blogs (risking major distraction) when you can simply stay
# in the console and ask howdoi:
#
# ::
#
#     $ howdoi format date bash
#     > DATE=`date +%Y-%m-%d`
#
# howdoi will answer all sorts of queries:
#
# ::
#
#     $ howdoi print stack trace python
#     > import traceback
#     >
#     > try:
#     >     1/0
#     > except:
# ...

# %%
!~/.local/bin/howdoi -e google convert geojson file to a shapefile
# Out:
# import shapefile
#    from json import dumps
#
#    # read the shapefile
#    reader = shapefile.Reader("my.shp")
#    fields = reader.fields[1:]
#    field_names = [field[0] for field in fields]
#    buffer = []
#    for sr in reader.shapeRecords():
#        atr = dict(zip(field_names, sr.record))
#        geom = sr.shape.__geo_interface__
#        buffer.append(dict(type="Feature", \
#         geometry=geom, properties=atr))
#
#    # write the GeoJSON file
#
#    geojson = open("pyshp-demo.json", "w")
#    geojson.write(dumps({"type": "FeatureCollection", "features": buffer}, indent=2) + "\n")
#    geojson.close()

# %%
!~/.local/bin/howdoi convert geojson file to an ESRI shapefile
# Out:
# import shapefile
#    from json import dumps
#
#    # read the shapefile
#    reader = shapefile.Reader("my.shp")
#    fields = reader.fields[1:]
#    field_names = [field[0] for field in fields]
#    buffer = []
#    for sr in reader.shapeRecords():
#        atr = dict(zip(field_names, sr.record))
#        geom = sr.shape.__geo_interface__
#        buffer.append(dict(type="Feature", \
#         geometry=geom, properties=atr))
#
#    # write the GeoJSON file
#
#    geojson = open("pyshp-demo.json", "w")
#    geojson.write(dumps({"type": "FeatureCollection", "features": buffer}, indent=2) + "\n")
#    geojson.close()

# %%
!~/.local/bin/howdoi -c convert mp4 to an animated gif
# Out:
# ffmpeg -i animated.gif -movflags faststart -pix_fmt yuv420p -vf "scale=trunc(iw/2)*2:trunc(ih/2)*2" video.mp4

# %%
!~/.local/bin/howdoi
# Out:
# usage: howdoi [-h] [-p POS] [-a] [-l] [-c] [-n NUM_ANSWERS] [-C] [-v]
#               [-e [SEARCH_ENGINE]]
#               [QUERY [QUERY ...]]
#
# instant coding answers via the command line
#
# positional arguments:
#   QUERY                 the question to answer
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -p POS, --pos POS     select answer in specified position (default: 1)
#   -a, --all             display the full text of the answer
#   -l, --link            display only the answer link
#   -c, --color           enable colorized output
#   -n NUM_ANSWERS, --num-answers NUM_ANSWERS
#                         number of answers to return
#   -C, --clear-cache     clear the cache
#   -v, --version         displays the current version of howdoi
#   -e [SEARCH_ENGINE], --engine [SEARCH_ENGINE]
#                         change search engine for this query only (google,
#                         bing, duckduckgo)

# %%
!~/.local/bin/howdoi -l convert mp4 to an animated gif
# Out:
# https://stackoverflow.com/questions/11004721/how-to-do-i-convert-an-animated-gif-to-an-mp4-or-mv4-on-the-command-line

# %% [markdown]
# ```
# jupyter-kagone@ip-10-12-68-72:~/files/cloud-veg-et/veget/api_veget$ howdoi convert a geojson file to a shapefile
# import urllib, geojson, gdal, subprocess
# url= ' http://ig3is.grid.unep.ch/istsos/wa/istsos/services/ghg/procedures/operations/geojson?epsg=4326'
# response = urllib.urlopen(url)
# data = geojson.loads(response.read())
#
# with open('data.geojson', 'w') as f:
#     geojson.dump(data, f)
#
# args = ['ogr2ogr', '-f', 'ESRI Shapefile', 'destination_data.shp', 'data.geojson']
# subprocess.Popen(args)
# ```

# %%
! ls ~/train/howdoi
# Out:
# CHANGES.txt  README.rst		 howdoi		  requirements.txt
# LICENSE.txt  __pycache__	 howdoi.egg-info  setup.py
# MANIFEST.in  fastentrypoints.py  howdoi.rb	  test_howdoi.py

# %%
! cat Makefile
# Out:
# run:
# 	python3 api_veget.py 40N-100E
#
# help:
# 	python3 api_veget.py --help
#
# git:
# 	echo Call Steffi and have her run make git in the root dir for this repo
#
# graph:
# 	pyan3 --dot api_veget.py | dot -Tsvg -o api.svg
# 	pyan3 --dot ../vegetLib/vegetLib/veget.py | dot -Tsvg -o veget.svg
#
# readme:
# 	echo https://github.com/tonybutzer/training/blob/master/craft/tools/README.md

# %%
! ls ~/train/howdoi
# Out:
# CHANGES.txt  README.rst		 howdoi		  requirements.txt
# LICENSE.txt  __pycache__	 howdoi.egg-info  setup.py
# MANIFEST.in  fastentrypoints.py  howdoi.rb	  test_howdoi.py

# %%
! cat ~/train/howdoi/requirements.txt
# Out:
# Pygments==2.2.0
# argparse==1.4.0
# cssselect==1.0.3
# lxml==4.2.5
# pyquery==1.4.0
# requests==2.20.1
# cachelib==0.1
# appdirs==1.4.3

# %%
! head -40 /home/jupyter-kagone/train/howdoi/setup.py
# Out:
# #!/usr/bin/env python
#
# from setuptools import setup, find_packages
# import fastentrypoints
# import howdoi
# import os
#
# def extra_dependencies():
#     import sys
#     return ['argparse'] if sys.version_info < (2, 7) else []
#
#
# def read(*names):
#     values = dict()
#     for name in names:
#         value = ''
#         for extension in ('.txt', '.rst'):
#             filename = name + extension
#             if os.path.isfile(filename):
#                 with open(filename) as in_file:
#                     value = in_file.read()
#                 break
#         values[name] = value
#     return values
#
#
# long_description = """
# %(README)s
#
# News
# ====
#
# %(CHANGES)s
#
# """ % read('README', 'CHANGES')
#
# setup(
#     name='howdoi',
#     version=howdoi.__version__,
#     description='Instant coding answers via the command line',

# %%
! cat /home/jupyter-kagone/train/howdoi/howdoi/*.py
# Out:
# __version__ = '1.2.1'
# #!/usr/bin/env python
#
# ######################################################
# #
# # howdoi - instant coding answers via the command line
# # written by Benjamin Gleitzman (gleitz@mit.edu)
# # inspired by Rich Jones (rich@anomos.info)
# #
# ######################################################
#
# from __future__ import print_function
# import gc
# gc.disable()  # noqa: E402
# import argparse
# import os
# import appdirs
# import re
# from cachelib import FileSystemCache, NullCache
# import requests
# import sys
# from . import __version__
#
# from pygments import highlight
# from pygments.lexers import guess_lexer, get_lexer_by_name
# from pygments.formatters.terminal import TerminalFormatter
# from pygments.util import ClassNotFound
#
# from pyquery import PyQuery as pq
# from requests.exceptions import ConnectionError
# from requests.exceptions import SSLError
#
# # Handle imports for Python 2 and 3
# if sys.version < '3':
#     import codecs
# ...

# %%
! cat api_veget.py
# Out:
# import argparse
#
# from vegetLib.veget import VegET
#
# from vegetLib.log_logger import log_make_logger
#
# def get_parser():
#     parser = argparse.ArgumentParser(description='Run the veget model with specified tile')
#     parser.add_argument('tile', metavar='TILE', type=str, nargs='*',
#             help='the tile to process - example: 40N-80E')
#     parser.add_argument('-c', '--configdir', help='specify and alternate config dir example: -c sample_config ', default='./sample_config', type=str)
#     return parser
#
#
# def command_line_runner():
#     parser = get_parser()
#     args = vars(parser.parse_args())
#
#     if args['configdir']:
#         print("configdir", args['configdir'])
#
#     if args['tile']:
#         print("tile", args['tile'])
#
#     tile = args['tile'][0]
#
#     config_directory = args['configdir']
#
#     print('Using config dir {} to process tile {}'.format(config_directory, tile))
#
#     log.info('Processing Tile {}'.format(tile))
#
# ...

# %%
! cat Makefile
# Out:
# run:
# 	python3 api_veget.py 40N-100E
#
# help:
# 	python3 api_veget.py --help
#
# git:
# 	echo Call Steffi and have her run make git in the root dir for this repo
#
# graph:
# 	pyan3 --dot api_veget.py | dot -Tsvg -o api.svg
# 	pyan3 --dot ../vegetLib/vegetLib/veget.py | dot -Tsvg -o veget.svg
#
# readme:
# 	echo https://github.com/tonybutzer/training/blob/master/craft/tools/README.md

# %%
! make
# Out:
# python3 api_veget.py 40N-100E
# 2020-05-27 14:24:20,360 - CLOUD_VEGET - INFO - Logging Begins
# configdir ./sample_config
# tile ['40N-100E']
# Using config dir ./sample_config to process tile 40N-100E
# 2020-05-27 14:24:20,362 - CLOUD_VEGET - INFO - Processing Tile 40N-100E
# 2020-05-27 14:24:20,362 - CLOUD_VEGET - ERROR - Someday tony needs to refine logging and determine a std format for ELK
# 2020-05-27 14:24:20,362 - CLOUD_VEGET - ERROR - or logging agents and logging backends ... docker deployments
# 2020-05-27 14:24:20,362 - VegET - INFO - Logging Begins
# 2020-05-27 14:24:20,371 - VegET - INFO - veget_config_path is ./sample_config
# ------------------------------------------------------------------------------------------
# ...

# %%
! make | grep 40
# Out:
# python3 api_veget.py 40N-100E
# 2020-05-27 14:26:05,551 - CLOUD_VEGET - INFO - Logging Begins
# 2020-05-27 14:26:05,553 - CLOUD_VEGET - INFO - Processing Tile 40N-100E
# 2020-05-27 14:26:05,553 - CLOUD_VEGET - ERROR - Someday tony needs to refine logging and determine a std format for ELK
# 2020-05-27 14:26:05,553 - CLOUD_VEGET - ERROR - or logging agents and logging backends ... docker deployments
# 2020-05-27 14:26:05,553 - VegET - INFO - Logging Begins
# 2020-05-27 14:26:05,559 - VegET - INFO - veget_config_path is ./sample_config
# 2020-05-27 14:26:05,559 - VegET - ERROR - This line below has a sys.exit(0) - not cool 90
# tile ['40N-100E']
# Using config dir ./sample_config to process tile 40N-100E

# %%
! make | grep config
# Out:
# 2020-05-27 14:26:08,913 - CLOUD_VEGET - INFO - Logging Begins
# 2020-05-27 14:26:08,915 - CLOUD_VEGET - INFO - Processing Tile 40N-100E
# 2020-05-27 14:26:08,915 - CLOUD_VEGET - ERROR - Someday tony needs to refine logging and determine a std format for ELK
# 2020-05-27 14:26:08,915 - CLOUD_VEGET - ERROR - or logging agents and logging backends ... docker deployments
# 2020-05-27 14:26:08,915 - VegET - INFO - Logging Begins
# 2020-05-27 14:26:08,925 - VegET - INFO - veget_config_path is ./sample_config
# 2020-05-27 14:26:08,925 - VegET - ERROR - This line below has a sys.exit(0) - not cool 90
# configdir ./sample_config
# Using config dir ./sample_config to process tile 40N-100E

# %%
# remember do this at the end of each day
# !make git
# Out:
# echo Call Steffi and have her run make git in the root dir for this repo
# Call Steffi and have her run make git in the root dir for this repo

# %% [markdown]
# # ssh keys perhaps - yes
#
# 1. run ssh-keygen in terminal - DONE

# %%
! ls ~/.ssh/
# Out:
# authorized_keys  id_rsa  id_rsa.pub

# %%
# this to be added to github valid keys
! cat ~/.ssh/id_rsa.pub
# Out:
# ssh-rsa  jupyter-kagone@ip-10-12-68-72

# %%
! ls /home/jupyter-kagone/files/cloud-veg-et/.git
# Out:
# COMMIT_EDITMSG	HEAD	   branches  description  index  logs	  packed-refs
# FETCH_HEAD	ORIG_HEAD  config    hooks	  info	 objects  refs

# %%
! cat /home/jupyter-kagone/files/cloud-veg-et/.git/config
# Out:
# [core]
# 	repositoryformatversion = 0
# 	filemode = true
# 	bare = false
# 	logallrefupdates = true
# [remote "origin"]
# 	url = https://github.com/skagone/cloud-veg-et.git
# 	fetch = +refs/heads/*:refs/remotes/origin/*
# [branch "master"]
# 	remote = origin
# 	merge = refs/heads/master

# %% [markdown]
# Modify a pre-existing repository
#
# As you already know, to switch a pre-existing repository to use SSH instead of HTTPS, you can change the remote url within your .git/config file.
#
# [remote "origin"]
#     fetch = +refs/heads/*:refs/remotes/origin/*
#     -url = https://github.com/nikhilbhardwaj/abc.git
#     +url = git@github.com:nikhilbhardwaj/abc.git
#
# A shortcut is to use the set-url command:
#
# $ git remote set-url origin git@github.com:nikhilbhardwaj/abc.git
#
#
# # git remote set-url origin git@github.com:skagone/cloud-veg-et.git
