# %%
# %%time
import os
import rasterio
from matplotlib import pyplot as plt
from s3fs.core import S3FileSystem

from vegetLib.veget import VegET
# todo add tile param
veggie = VegET(veget_config_path=r'./sample_config', tile='40N-80E')

veggie.run_veg_et()

# s3 = S3FileSystem()
# p1 = 'dev-et-data/v1DRB_outputs'
# p2 = 'model_outputs/etasw_2015.tif'
# p = os.path.join(p1, p2)
# #p = 'dev-et-data/NA_data_for_cloud/global_water_mask_inland.tif'

# ps3 = s3.open(p)
# print(ps3)
# Out:
# 2020-06-01 19:55:43,634 - BOXY_THINGYS - INFO - Logging Begins
# 2020-06-01 19:55:43,636 - VegET_CLASS - INFO - Logging Begins
# 2020-06-01 19:55:43,637 - VegET_CLASS - INFO - 40N-80E
# 2020-06-01 19:55:43,662 - COOL RASTERMANAGER - INFO - Logging Begins
# 2020-06-01 19:55:43,664 - COOL RASTERMANAGER - INFO - Tony-s stupid - tile name is - 40N-80E
# 2020-06-01 19:55:43,665 - COOL RASTERMANAGER - INFO - temp folder is
# 2020-06-01 19:55:43,666 - BOXY_THINGYS - INFO - temp dir here is ./40N-80E
# 2020-06-01 19:55:43,667 - BOXY_THINGYS - INFO - created simple geojson file named ./40N-80E/40N-80E.json
# 2020-06-01 19:55:43,668 - BOXY_THINGYS - INFO - this file ./40N-80E/40N-80E.json is github ready and no ESRI influence
# ------------------------------------------------------------------------------------------
# [[-80, 40], [-70, 40], [-70, 30], [-80, 30], [-80, 40]]
#              _ _            ___  ___  _  _
#             | | | ___  ___ | __>|_ _|| || |
#             | ' |/ ._>/ . || _>  | | |_/|_/
#             |__/ \___.\_. ||___> |_| <_><_>
#                        <___'
# 2013-10-02 00:00:00
# 2016-01-01 00:00:00
# 821
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Soil/global/inp.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Soil/global/whc.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Soil/global/fdc.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Soil/global/sat.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/global_water_mask_inland.tif
# <class 'rasterio.vrt.WarpedVRT'>
# settings {'name_fmt': 'med{}.250_m_NDVI.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NDVI_filled/med2003_2017', 'climatology': True}
# settings {'name_fmt': 'pet{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/', 'climatology': True}
# settings {'name_fmt': 'prec_{}.tif', 'dt_fmt': 'YYYYdoy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico', 'climatology': False, 'na_vals': []}
# settings {'name_fmt': 'tavg_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmin_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmax_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily', 'climatology': True}
# warpfile /vsis3/dev-et-data/NDVI_filled/med2003_2017/med275.250_m_NDVI.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/pet275.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico/2013/prec_2013275.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily/tavg_275.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily/tmin_275.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily/tmax_275.tif
# <class 'rasterio.vrt.WarpedVRT'>
# ppt min -3.4028234663852886e+38
# ppt max -3.4028234663852886e+38
# ppt min nan
# ppt max nan
# tavg min -3.4028234663852886e+38
# tavg min nan
# interception min nan
# /home/jupyter-kagone/files/cloud-veg-et/veget/vegetLib/vegetLib/veget.py:185: RuntimeWarning: invalid value encountered in less_equal
#   snow_melt_fac[tavg <= rf_high_thresh_temp] = melt_rate[tavg <= rf_high_thresh_temp]
# /home/jupyter-kagone/files/cloud-veg-et/veget/vegetLib/vegetLib/veget.py:186: RuntimeWarning: invalid value encountered in greater
#   snow_melt_fac[tavg > rf_high_thresh_temp] = 0
# /home/jupyter-kagone/files/cloud-veg-et/veget/vegetLib/vegetLib/veget.py:193: RuntimeWarning: invalid value encountered in less_equal
#   rain_frac[tavg <= rf_low_thresh_temp] = 0
# /home/jupyter-kagone/files/cloud-veg-et/veget/vegetLib/vegetLib/veget.py:194: RuntimeWarning: invalid value encountered in greater_equal
#   rain_frac[tavg >= rf_high_thresh_temp] = 1
# /home/jupyter-kagone/files/cloud-veg-et/veget/vegetLib/vegetLib/veget.py:195: RuntimeWarning: invalid value encountered in less
#   temp_diff_boolean = (tavg < rf_high_thresh_temp) | (tavg > rf_low_thresh_temp)
# /home/jupyter-kagone/files/cloud-veg-et/veget/vegetLib/vegetLib/veget.py:195: RuntimeWarning: invalid value encountered in greater
#   temp_diff_boolean = (tavg < rf_high_thresh_temp) | (tavg > rf_low_thresh_temp)
# /home/jupyter-kagone/files/cloud-veg-et/veget/vegetLib/vegetLib/veget.py:203: RuntimeWarning: invalid value encountered in less
#   SWi[SWi < 0] = np.nan
# 2013 10 2
# today is 275
# swout swi_2013275.tif
# /home/jupyter-kagone/files/cloud-veg-et/veget/vegetLib/vegetLib/veget.py:260: RuntimeWarning: invalid value encountered in greater_equal
#   rf_boolean = (Rf1 >= 0)
# /home/jupyter-kagone/files/cloud-veg-et/veget/vegetLib/vegetLib/veget.py:266: RuntimeWarning: invalid value encountered in less_equal
#   SRf_boolean = (Rf <= sat_fc)
# /home/jupyter-kagone/files/cloud-veg-et/veget/vegetLib/vegetLib/veget.py:305: RuntimeWarning: invalid value encountered in true_divide
#   etasw2 = (SWi / (0.5 * self.whc)) * etasw1
# /home/jupyter-kagone/files/cloud-veg-et/veget/vegetLib/vegetLib/veget.py:308: RuntimeWarning: invalid value encountered in greater
#   etasw3_boolean = (etasw3 > SWi)
# /home/jupyter-kagone/files/cloud-veg-et/veget/vegetLib/vegetLib/veget.py:313: RuntimeWarning: invalid value encountered in greater
#   etasw4_boolean = (etasw3 > SWi)
# /home/jupyter-kagone/files/cloud-veg-et/veget/vegetLib/vegetLib/veget.py:318: RuntimeWarning: invalid value encountered in greater
#   etasw_boolean = (etasw4 > self.whc)
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# /home/jupyter-kagone/files/cloud-veg-et/veget/vegetLib/vegetLib/veget.py:338: RuntimeWarning: invalid value encountered in greater
#   SWf_boolean = (SWi > self.whc)
# /home/jupyter-kagone/files/cloud-veg-et/veget/vegetLib/vegetLib/veget.py:339: RuntimeWarning: invalid value encountered in less
#   SWf_boolean2 = (SWf1 < 0.0)
# -------------------------------
# output monthly is False and output yearly is False
# settings {'name_fmt': 'med{}.250_m_NDVI.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NDVI_filled/med2003_2017', 'climatology': True}
# settings {'name_fmt': 'pet{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/', 'climatology': True}
# settings {'name_fmt': 'prec_{}.tif', 'dt_fmt': 'YYYYdoy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico', 'climatology': False, 'na_vals': []}
# settings {'name_fmt': 'tavg_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmin_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmax_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily', 'climatology': True}
# warpfile /vsis3/dev-et-data/NDVI_filled/med2003_2017/med276.250_m_NDVI.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/pet276.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico/2013/prec_2013276.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily/tavg_276.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily/tmin_276.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily/tmax_276.tif
# <class 'rasterio.vrt.WarpedVRT'>
# ppt min -3.4028234663852886e+38
# ppt max -3.4028234663852886e+38
# ppt min nan
# ppt max nan
# tavg min -3.4028234663852886e+38
# tavg min nan
# interception min nan
# /home/jupyter-kagone/files/cloud-veg-et/veget/vegetLib/vegetLib/veget.py:212: RuntimeWarning: invalid value encountered in less_equal
#   rain_frac[tavg <= rf_low_thresh_temp] = 0
# /home/jupyter-kagone/files/cloud-veg-et/veget/vegetLib/vegetLib/veget.py:213: RuntimeWarning: invalid value encountered in greater_equal
#   rain_frac[tavg >= rf_high_thresh_temp] = 1
# /home/jupyter-kagone/files/cloud-veg-et/veget/vegetLib/vegetLib/veget.py:214: RuntimeWarning: invalid value encountered in less
#   temp_diff_boolean = (tavg < rf_high_thresh_temp) | (tavg > rf_low_thresh_temp)
# /home/jupyter-kagone/files/cloud-veg-et/veget/vegetLib/vegetLib/veget.py:214: RuntimeWarning: invalid value encountered in greater
#   temp_diff_boolean = (tavg < rf_high_thresh_temp) | (tavg > rf_low_thresh_temp)
# /home/jupyter-kagone/files/cloud-veg-et/veget/vegetLib/vegetLib/veget.py:223: RuntimeWarning: invalid value encountered in less_equal
#   snow_melt_boolean = (melt_rate <= (SWE + yest_snwpck))
# /home/jupyter-kagone/files/cloud-veg-et/veget/vegetLib/vegetLib/veget.py:231: RuntimeWarning: invalid value encountered in less
#   SNWpk[SNWpk1 < 0] = 0
# /home/jupyter-kagone/files/cloud-veg-et/veget/vegetLib/vegetLib/veget.py:232: RuntimeWarning: invalid value encountered in greater_equal
#   SNWpk[SNWpk1 >= 0] = SNWpk1[SNWpk1 >= 0]
# 2013 10 3
# today is 276
# swout swi_2013276.tif
# /home/jupyter-kagone/files/cloud-veg-et/veget/vegetLib/vegetLib/veget.py:251: RuntimeWarning: invalid value encountered in less
#   saturation[saturation < 0] = np.nan
# /home/jupyter-kagone/files/cloud-veg-et/veget/vegetLib/vegetLib/veget.py:252: RuntimeWarning: invalid value encountered in less
#   field_capacity[field_capacity < 0] = np.nan
# /home/jupyter-kagone/files/cloud-veg-et/veget/vegetLib/vegetLib/veget.py:253: RuntimeWarning: invalid value encountered in less
#   whc[whc < 0] = np.nan
# /home/jupyter-kagone/files/cloud-veg-et/veget/vegetLib/vegetLib/veget.py:305: RuntimeWarning: divide by zero encountered in true_divide
#   etasw2 = (SWi / (0.5 * self.whc)) * etasw1
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# -------------------------------
# output monthly is False and output yearly is False
# settings {'name_fmt': 'med{}.250_m_NDVI.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NDVI_filled/med2003_2017', 'climatology': True}
# settings {'name_fmt': 'pet{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/', 'climatology': True}
# settings {'name_fmt': 'prec_{}.tif', 'dt_fmt': 'YYYYdoy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico', 'climatology': False, 'na_vals': []}
# settings {'name_fmt': 'tavg_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmin_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmax_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily', 'climatology': True}
# warpfile /vsis3/dev-et-data/NDVI_filled/med2003_2017/med277.250_m_NDVI.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/pet277.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico/2013/prec_2013277.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily/tavg_277.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily/tmin_277.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily/tmax_277.tif
# <class 'rasterio.vrt.WarpedVRT'>
# ppt min -3.4028234663852886e+38
# ppt max -3.4028234663852886e+38
# ppt min nan
# ppt max nan
# tavg min -3.4028234663852886e+38
# tavg min nan
# interception min nan
# 2013 10 4
# today is 277
# swout swi_2013277.tif
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# -------------------------------
# output monthly is False and output yearly is False
# settings {'name_fmt': 'med{}.250_m_NDVI.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NDVI_filled/med2003_2017', 'climatology': True}
# settings {'name_fmt': 'pet{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/', 'climatology': True}
# settings {'name_fmt': 'prec_{}.tif', 'dt_fmt': 'YYYYdoy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico', 'climatology': False, 'na_vals': []}
# settings {'name_fmt': 'tavg_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmin_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmax_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily', 'climatology': True}
# warpfile /vsis3/dev-et-data/NDVI_filled/med2003_2017/med278.250_m_NDVI.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/pet278.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico/2013/prec_2013278.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily/tavg_278.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily/tmin_278.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily/tmax_278.tif
# <class 'rasterio.vrt.WarpedVRT'>
# ppt min -3.4028234663852886e+38
# ppt max -3.4028234663852886e+38
# ppt min nan
# ppt max nan
# tavg min -3.4028234663852886e+38
# tavg min nan
# interception min nan
# 2013 10 5
# today is 278
# swout swi_2013278.tif
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# -------------------------------
# output monthly is False and output yearly is False
# settings {'name_fmt': 'med{}.250_m_NDVI.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NDVI_filled/med2003_2017', 'climatology': True}
# settings {'name_fmt': 'pet{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/', 'climatology': True}
# settings {'name_fmt': 'prec_{}.tif', 'dt_fmt': 'YYYYdoy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico', 'climatology': False, 'na_vals': []}
# settings {'name_fmt': 'tavg_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmin_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmax_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily', 'climatology': True}
# warpfile /vsis3/dev-et-data/NDVI_filled/med2003_2017/med279.250_m_NDVI.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/pet279.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico/2013/prec_2013279.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily/tavg_279.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily/tmin_279.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily/tmax_279.tif
# <class 'rasterio.vrt.WarpedVRT'>
# ppt min -3.4028234663852886e+38
# ppt max -3.4028234663852886e+38
# ppt min nan
# ppt max nan
# tavg min -3.4028234663852886e+38
# tavg min nan
# interception min nan
# 2013 10 6
# today is 279
# swout swi_2013279.tif
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# -------------------------------
# output monthly is False and output yearly is False
# settings {'name_fmt': 'med{}.250_m_NDVI.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NDVI_filled/med2003_2017', 'climatology': True}
# settings {'name_fmt': 'pet{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/', 'climatology': True}
# settings {'name_fmt': 'prec_{}.tif', 'dt_fmt': 'YYYYdoy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico', 'climatology': False, 'na_vals': []}
# settings {'name_fmt': 'tavg_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmin_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmax_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily', 'climatology': True}
# warpfile /vsis3/dev-et-data/NDVI_filled/med2003_2017/med280.250_m_NDVI.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/pet280.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico/2013/prec_2013280.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily/tavg_280.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily/tmin_280.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily/tmax_280.tif
# <class 'rasterio.vrt.WarpedVRT'>
# ppt min -3.4028234663852886e+38
# ppt max -3.4028234663852886e+38
# ppt min nan
# ppt max nan
# tavg min -3.4028234663852886e+38
# tavg min nan
# interception min nan
# 2013 10 7
# today is 280
# swout swi_2013280.tif
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# -------------------------------
# output monthly is False and output yearly is False
# settings {'name_fmt': 'med{}.250_m_NDVI.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NDVI_filled/med2003_2017', 'climatology': True}
# settings {'name_fmt': 'pet{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/', 'climatology': True}
# settings {'name_fmt': 'prec_{}.tif', 'dt_fmt': 'YYYYdoy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico', 'climatology': False, 'na_vals': []}
# settings {'name_fmt': 'tavg_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmin_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmax_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily', 'climatology': True}
# warpfile /vsis3/dev-et-data/NDVI_filled/med2003_2017/med281.250_m_NDVI.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/pet281.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico/2013/prec_2013281.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily/tavg_281.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily/tmin_281.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily/tmax_281.tif
# <class 'rasterio.vrt.WarpedVRT'>
# ppt min -3.4028234663852886e+38
# ppt max -3.4028234663852886e+38
# ppt min nan
# ppt max nan
# tavg min -3.4028234663852886e+38
# tavg min nan
# interception min nan
# 2013 10 8
# today is 281
# swout swi_2013281.tif
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# -------------------------------
# output monthly is False and output yearly is False
# settings {'name_fmt': 'med{}.250_m_NDVI.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NDVI_filled/med2003_2017', 'climatology': True}
# settings {'name_fmt': 'pet{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/', 'climatology': True}
# settings {'name_fmt': 'prec_{}.tif', 'dt_fmt': 'YYYYdoy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico', 'climatology': False, 'na_vals': []}
# settings {'name_fmt': 'tavg_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmin_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmax_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily', 'climatology': True}
# warpfile /vsis3/dev-et-data/NDVI_filled/med2003_2017/med282.250_m_NDVI.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/pet282.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico/2013/prec_2013282.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily/tavg_282.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily/tmin_282.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily/tmax_282.tif
# <class 'rasterio.vrt.WarpedVRT'>
# ppt min -3.4028234663852886e+38
# ppt max -3.4028234663852886e+38
# ppt min nan
# ppt max nan
# tavg min -3.4028234663852886e+38
# tavg min nan
# interception min nan
# 2013 10 9
# today is 282
# swout swi_2013282.tif
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# -------------------------------
# output monthly is False and output yearly is False
# settings {'name_fmt': 'med{}.250_m_NDVI.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NDVI_filled/med2003_2017', 'climatology': True}
# settings {'name_fmt': 'pet{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/', 'climatology': True}
# settings {'name_fmt': 'prec_{}.tif', 'dt_fmt': 'YYYYdoy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico', 'climatology': False, 'na_vals': []}
# settings {'name_fmt': 'tavg_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmin_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmax_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily', 'climatology': True}
# warpfile /vsis3/dev-et-data/NDVI_filled/med2003_2017/med283.250_m_NDVI.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/pet283.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico/2013/prec_2013283.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily/tavg_283.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily/tmin_283.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily/tmax_283.tif
# <class 'rasterio.vrt.WarpedVRT'>
# ppt min -3.4028234663852886e+38
# ppt max -3.4028234663852886e+38
# ppt min nan
# ppt max nan
# tavg min -3.4028234663852886e+38
# tavg min nan
# interception min nan
# 2013 10 10
# today is 283
# swout swi_2013283.tif
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# -------------------------------
# output monthly is False and output yearly is False
# settings {'name_fmt': 'med{}.250_m_NDVI.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NDVI_filled/med2003_2017', 'climatology': True}
# settings {'name_fmt': 'pet{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/', 'climatology': True}
# settings {'name_fmt': 'prec_{}.tif', 'dt_fmt': 'YYYYdoy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico', 'climatology': False, 'na_vals': []}
# settings {'name_fmt': 'tavg_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmin_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmax_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily', 'climatology': True}
# warpfile /vsis3/dev-et-data/NDVI_filled/med2003_2017/med284.250_m_NDVI.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/pet284.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico/2013/prec_2013284.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily/tavg_284.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily/tmin_284.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily/tmax_284.tif
# <class 'rasterio.vrt.WarpedVRT'>
# ppt min -3.4028234663852886e+38
# ppt max -3.4028234663852886e+38
# ppt min nan
# ppt max nan
# tavg min -3.4028234663852886e+38
# tavg min nan
# interception min nan
# 2013 10 11
# today is 284
# swout swi_2013284.tif
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# -------------------------------
# output monthly is False and output yearly is False
# settings {'name_fmt': 'med{}.250_m_NDVI.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NDVI_filled/med2003_2017', 'climatology': True}
# settings {'name_fmt': 'pet{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/', 'climatology': True}
# settings {'name_fmt': 'prec_{}.tif', 'dt_fmt': 'YYYYdoy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico', 'climatology': False, 'na_vals': []}
# settings {'name_fmt': 'tavg_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmin_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmax_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily', 'climatology': True}
# warpfile /vsis3/dev-et-data/NDVI_filled/med2003_2017/med285.250_m_NDVI.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/pet285.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico/2013/prec_2013285.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily/tavg_285.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily/tmin_285.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily/tmax_285.tif
# <class 'rasterio.vrt.WarpedVRT'>
# ppt min -3.4028234663852886e+38
# ppt max -3.4028234663852886e+38
# ppt min nan
# ppt max nan
# tavg min -3.4028234663852886e+38
# tavg min nan
# interception min nan
# 2013 10 12
# today is 285
# swout swi_2013285.tif
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# -------------------------------
# output monthly is False and output yearly is False
# settings {'name_fmt': 'med{}.250_m_NDVI.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NDVI_filled/med2003_2017', 'climatology': True}
# settings {'name_fmt': 'pet{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/', 'climatology': True}
# settings {'name_fmt': 'prec_{}.tif', 'dt_fmt': 'YYYYdoy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico', 'climatology': False, 'na_vals': []}
# settings {'name_fmt': 'tavg_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmin_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmax_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily', 'climatology': True}
# warpfile /vsis3/dev-et-data/NDVI_filled/med2003_2017/med286.250_m_NDVI.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/pet286.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico/2013/prec_2013286.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily/tavg_286.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily/tmin_286.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily/tmax_286.tif
# <class 'rasterio.vrt.WarpedVRT'>
# ppt min -3.4028234663852886e+38
# ppt max -3.4028234663852886e+38
# ppt min nan
# ppt max nan
# tavg min -3.4028234663852886e+38
# tavg min nan
# interception min nan
# 2013 10 13
# today is 286
# swout swi_2013286.tif
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# -------------------------------
# output monthly is False and output yearly is False
# settings {'name_fmt': 'med{}.250_m_NDVI.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NDVI_filled/med2003_2017', 'climatology': True}
# settings {'name_fmt': 'pet{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/', 'climatology': True}
# settings {'name_fmt': 'prec_{}.tif', 'dt_fmt': 'YYYYdoy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico', 'climatology': False, 'na_vals': []}
# settings {'name_fmt': 'tavg_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmin_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmax_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily', 'climatology': True}
# warpfile /vsis3/dev-et-data/NDVI_filled/med2003_2017/med287.250_m_NDVI.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/pet287.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico/2013/prec_2013287.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily/tavg_287.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily/tmin_287.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily/tmax_287.tif
# <class 'rasterio.vrt.WarpedVRT'>
# ppt min -3.4028234663852886e+38
# ppt max -3.4028234663852886e+38
# ppt min nan
# ppt max nan
# tavg min -3.4028234663852886e+38
# tavg min nan
# interception min nan
# 2013 10 14
# today is 287
# swout swi_2013287.tif
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# -------------------------------
# output monthly is False and output yearly is False
# settings {'name_fmt': 'med{}.250_m_NDVI.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NDVI_filled/med2003_2017', 'climatology': True}
# settings {'name_fmt': 'pet{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/', 'climatology': True}
# settings {'name_fmt': 'prec_{}.tif', 'dt_fmt': 'YYYYdoy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico', 'climatology': False, 'na_vals': []}
# settings {'name_fmt': 'tavg_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmin_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmax_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily', 'climatology': True}
# warpfile /vsis3/dev-et-data/NDVI_filled/med2003_2017/med288.250_m_NDVI.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/pet288.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico/2013/prec_2013288.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily/tavg_288.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily/tmin_288.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily/tmax_288.tif
# <class 'rasterio.vrt.WarpedVRT'>
# ppt min -3.4028234663852886e+38
# ppt max -3.4028234663852886e+38
# ppt min nan
# ppt max nan
# tavg min -3.4028234663852886e+38
# tavg min nan
# interception min nan
# 2013 10 15
# today is 288
# swout swi_2013288.tif
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# -------------------------------
# output monthly is False and output yearly is False
# settings {'name_fmt': 'med{}.250_m_NDVI.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NDVI_filled/med2003_2017', 'climatology': True}
# settings {'name_fmt': 'pet{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/', 'climatology': True}
# settings {'name_fmt': 'prec_{}.tif', 'dt_fmt': 'YYYYdoy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico', 'climatology': False, 'na_vals': []}
# settings {'name_fmt': 'tavg_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmin_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmax_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily', 'climatology': True}
# warpfile /vsis3/dev-et-data/NDVI_filled/med2003_2017/med289.250_m_NDVI.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/pet289.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico/2013/prec_2013289.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily/tavg_289.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily/tmin_289.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily/tmax_289.tif
# <class 'rasterio.vrt.WarpedVRT'>
# ppt min -3.4028234663852886e+38
# ppt max -3.4028234663852886e+38
# ppt min nan
# ppt max nan
# tavg min -3.4028234663852886e+38
# tavg min nan
# interception min nan
# 2013 10 16
# today is 289
# swout swi_2013289.tif
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# -------------------------------
# output monthly is False and output yearly is False
# settings {'name_fmt': 'med{}.250_m_NDVI.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NDVI_filled/med2003_2017', 'climatology': True}
# settings {'name_fmt': 'pet{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/', 'climatology': True}
# settings {'name_fmt': 'prec_{}.tif', 'dt_fmt': 'YYYYdoy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico', 'climatology': False, 'na_vals': []}
# settings {'name_fmt': 'tavg_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmin_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmax_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily', 'climatology': True}
# warpfile /vsis3/dev-et-data/NDVI_filled/med2003_2017/med290.250_m_NDVI.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/pet290.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico/2013/prec_2013290.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily/tavg_290.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily/tmin_290.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily/tmax_290.tif
# <class 'rasterio.vrt.WarpedVRT'>
# ppt min -3.4028234663852886e+38
# ppt max -3.4028234663852886e+38
# ppt min nan
# ppt max nan
# tavg min -3.4028234663852886e+38
# tavg min nan
# interception min nan
# 2013 10 17
# today is 290
# swout swi_2013290.tif
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# -------------------------------
# output monthly is False and output yearly is False
# settings {'name_fmt': 'med{}.250_m_NDVI.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NDVI_filled/med2003_2017', 'climatology': True}
# settings {'name_fmt': 'pet{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/', 'climatology': True}
# settings {'name_fmt': 'prec_{}.tif', 'dt_fmt': 'YYYYdoy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico', 'climatology': False, 'na_vals': []}
# settings {'name_fmt': 'tavg_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmin_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmax_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily', 'climatology': True}
# warpfile /vsis3/dev-et-data/NDVI_filled/med2003_2017/med291.250_m_NDVI.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/pet291.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico/2013/prec_2013291.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily/tavg_291.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily/tmin_291.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily/tmax_291.tif
# <class 'rasterio.vrt.WarpedVRT'>
# ppt min -3.4028234663852886e+38
# ppt max -3.4028234663852886e+38
# ppt min nan
# ppt max nan
# tavg min -3.4028234663852886e+38
# tavg min nan
# interception min nan
# 2013 10 18
# today is 291
# swout swi_2013291.tif
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# -------------------------------
# output monthly is False and output yearly is False
# settings {'name_fmt': 'med{}.250_m_NDVI.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NDVI_filled/med2003_2017', 'climatology': True}
# settings {'name_fmt': 'pet{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/', 'climatology': True}
# settings {'name_fmt': 'prec_{}.tif', 'dt_fmt': 'YYYYdoy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico', 'climatology': False, 'na_vals': []}
# settings {'name_fmt': 'tavg_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmin_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmax_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily', 'climatology': True}
# warpfile /vsis3/dev-et-data/NDVI_filled/med2003_2017/med292.250_m_NDVI.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/pet292.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico/2013/prec_2013292.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily/tavg_292.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily/tmin_292.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily/tmax_292.tif
# <class 'rasterio.vrt.WarpedVRT'>
# ppt min -3.4028234663852886e+38
# ppt max -3.4028234663852886e+38
# ppt min nan
# ppt max nan
# tavg min -3.4028234663852886e+38
# tavg min nan
# interception min nan
# 2013 10 19
# today is 292
# swout swi_2013292.tif
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# -------------------------------
# output monthly is False and output yearly is False
# settings {'name_fmt': 'med{}.250_m_NDVI.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NDVI_filled/med2003_2017', 'climatology': True}
# settings {'name_fmt': 'pet{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/', 'climatology': True}
# settings {'name_fmt': 'prec_{}.tif', 'dt_fmt': 'YYYYdoy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico', 'climatology': False, 'na_vals': []}
# settings {'name_fmt': 'tavg_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmin_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmax_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily', 'climatology': True}
# warpfile /vsis3/dev-et-data/NDVI_filled/med2003_2017/med293.250_m_NDVI.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/pet293.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico/2013/prec_2013293.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily/tavg_293.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily/tmin_293.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily/tmax_293.tif
# <class 'rasterio.vrt.WarpedVRT'>
# ppt min -3.4028234663852886e+38
# ppt max -3.4028234663852886e+38
# ppt min nan
# ppt max nan
# tavg min -3.4028234663852886e+38
# tavg min nan
# interception min nan
# 2013 10 20
# today is 293
# swout swi_2013293.tif
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# -------------------------------
# output monthly is False and output yearly is False
# settings {'name_fmt': 'med{}.250_m_NDVI.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NDVI_filled/med2003_2017', 'climatology': True}
# settings {'name_fmt': 'pet{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/', 'climatology': True}
# settings {'name_fmt': 'prec_{}.tif', 'dt_fmt': 'YYYYdoy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico', 'climatology': False, 'na_vals': []}
# settings {'name_fmt': 'tavg_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmin_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmax_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily', 'climatology': True}
# warpfile /vsis3/dev-et-data/NDVI_filled/med2003_2017/med294.250_m_NDVI.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/pet294.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico/2013/prec_2013294.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily/tavg_294.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily/tmin_294.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily/tmax_294.tif
# <class 'rasterio.vrt.WarpedVRT'>
# ppt min -3.4028234663852886e+38
# ppt max -3.4028234663852886e+38
# ppt min nan
# ppt max nan
# tavg min -3.4028234663852886e+38
# tavg min nan
# interception min nan
# 2013 10 21
# today is 294
# swout swi_2013294.tif
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# -------------------------------
# output monthly is False and output yearly is False
# settings {'name_fmt': 'med{}.250_m_NDVI.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NDVI_filled/med2003_2017', 'climatology': True}
# settings {'name_fmt': 'pet{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/', 'climatology': True}
# settings {'name_fmt': 'prec_{}.tif', 'dt_fmt': 'YYYYdoy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico', 'climatology': False, 'na_vals': []}
# settings {'name_fmt': 'tavg_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmin_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmax_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily', 'climatology': True}
# warpfile /vsis3/dev-et-data/NDVI_filled/med2003_2017/med295.250_m_NDVI.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/pet295.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico/2013/prec_2013295.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily/tavg_295.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily/tmin_295.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily/tmax_295.tif
# <class 'rasterio.vrt.WarpedVRT'>
# ppt min -3.4028234663852886e+38
# ppt max -3.4028234663852886e+38
# ppt min nan
# ppt max nan
# tavg min -3.4028234663852886e+38
# tavg min nan
# interception min nan
# 2013 10 22
# today is 295
# swout swi_2013295.tif
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# -------------------------------
# output monthly is False and output yearly is False
# settings {'name_fmt': 'med{}.250_m_NDVI.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NDVI_filled/med2003_2017', 'climatology': True}
# settings {'name_fmt': 'pet{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/', 'climatology': True}
# settings {'name_fmt': 'prec_{}.tif', 'dt_fmt': 'YYYYdoy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico', 'climatology': False, 'na_vals': []}
# settings {'name_fmt': 'tavg_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmin_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmax_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily', 'climatology': True}
# ...
# settings {'name_fmt': 'tmin_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmax_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily', 'climatology': True}
# warpfile /vsis3/dev-et-data/NDVI_filled/med2003_2017/med025.250_m_NDVI.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/pet025.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico/2014/prec_2014025.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily/tavg_025.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily/tmin_025.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily/tmax_025.tif
# <class 'rasterio.vrt.WarpedVRT'>
# ppt min -3.4028234663852886e+38
# ppt max -3.4028234663852886e+38
# ppt min nan
# ppt max nan
# tavg min -3.4028234663852886e+38
# tavg min nan
# interception min nan
# 2014 1 25
# today is 025
# swout swi_2014025.tif
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# -------------------------------
# output monthly is False and output yearly is False
# settings {'name_fmt': 'med{}.250_m_NDVI.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NDVI_filled/med2003_2017', 'climatology': True}
# settings {'name_fmt': 'pet{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/', 'climatology': True}
# settings {'name_fmt': 'prec_{}.tif', 'dt_fmt': 'YYYYdoy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico', 'climatology': False, 'na_vals': []}
# settings {'name_fmt': 'tavg_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmin_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmax_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily', 'climatology': True}
# warpfile /vsis3/dev-et-data/NDVI_filled/med2003_2017/med026.250_m_NDVI.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/pet026.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico/2014/prec_2014026.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily/tavg_026.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily/tmin_026.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily/tmax_026.tif
# <class 'rasterio.vrt.WarpedVRT'>
# ppt min -3.4028234663852886e+38
# ppt max -3.4028234663852886e+38
# ppt min nan
# ppt max nan
# tavg min -3.4028234663852886e+38
# tavg min nan
# interception min nan
# 2014 1 26
# today is 026
# swout swi_2014026.tif
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# -------------------------------
# output monthly is False and output yearly is False
# settings {'name_fmt': 'med{}.250_m_NDVI.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NDVI_filled/med2003_2017', 'climatology': True}
# settings {'name_fmt': 'pet{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/', 'climatology': True}
# settings {'name_fmt': 'prec_{}.tif', 'dt_fmt': 'YYYYdoy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico', 'climatology': False, 'na_vals': []}
# settings {'name_fmt': 'tavg_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmin_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmax_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily', 'climatology': True}
# warpfile /vsis3/dev-et-data/NDVI_filled/med2003_2017/med027.250_m_NDVI.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/pet027.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico/2014/prec_2014027.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily/tavg_027.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily/tmin_027.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily/tmax_027.tif
# <class 'rasterio.vrt.WarpedVRT'>
# ppt min -3.4028234663852886e+38
# ppt max -3.4028234663852886e+38
# ppt min nan
# ppt max nan
# tavg min -3.4028234663852886e+38
# tavg min nan
# interception min nan
# 2014 1 27
# today is 027
# swout swi_2014027.tif
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# -------------------------------
# output monthly is False and output yearly is False
# settings {'name_fmt': 'med{}.250_m_NDVI.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NDVI_filled/med2003_2017', 'climatology': True}
# settings {'name_fmt': 'pet{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/', 'climatology': True}
# settings {'name_fmt': 'prec_{}.tif', 'dt_fmt': 'YYYYdoy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico', 'climatology': False, 'na_vals': []}
# settings {'name_fmt': 'tavg_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmin_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmax_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily', 'climatology': True}
# warpfile /vsis3/dev-et-data/NDVI_filled/med2003_2017/med028.250_m_NDVI.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/pet028.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico/2014/prec_2014028.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily/tavg_028.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily/tmin_028.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily/tmax_028.tif
# <class 'rasterio.vrt.WarpedVRT'>
# ppt min -3.4028234663852886e+38
# ppt max -3.4028234663852886e+38
# ppt min nan
# ppt max nan
# tavg min -3.4028234663852886e+38
# tavg min nan
# interception min nan
# 2014 1 28
# today is 028
# swout swi_2014028.tif
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# -------------------------------
# output monthly is False and output yearly is False
# settings {'name_fmt': 'med{}.250_m_NDVI.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NDVI_filled/med2003_2017', 'climatology': True}
# settings {'name_fmt': 'pet{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/', 'climatology': True}
# settings {'name_fmt': 'prec_{}.tif', 'dt_fmt': 'YYYYdoy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico', 'climatology': False, 'na_vals': []}
# settings {'name_fmt': 'tavg_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmin_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmax_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily', 'climatology': True}
# warpfile /vsis3/dev-et-data/NDVI_filled/med2003_2017/med029.250_m_NDVI.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/pet029.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico/2014/prec_2014029.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily/tavg_029.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily/tmin_029.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily/tmax_029.tif
# <class 'rasterio.vrt.WarpedVRT'>
# ppt min -3.4028234663852886e+38
# ppt max -3.4028234663852886e+38
# ppt min nan
# ppt max nan
# tavg min -3.4028234663852886e+38
# tavg min nan
# interception min nan
# 2014 1 29
# today is 029
# swout swi_2014029.tif
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# -------------------------------
# output monthly is False and output yearly is False
# settings {'name_fmt': 'med{}.250_m_NDVI.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NDVI_filled/med2003_2017', 'climatology': True}
# settings {'name_fmt': 'pet{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/', 'climatology': True}
# settings {'name_fmt': 'prec_{}.tif', 'dt_fmt': 'YYYYdoy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico', 'climatology': False, 'na_vals': []}
# settings {'name_fmt': 'tavg_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmin_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmax_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily', 'climatology': True}
# warpfile /vsis3/dev-et-data/NDVI_filled/med2003_2017/med030.250_m_NDVI.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/pet030.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico/2014/prec_2014030.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily/tavg_030.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily/tmin_030.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily/tmax_030.tif
# <class 'rasterio.vrt.WarpedVRT'>
# ppt min -3.4028234663852886e+38
# ppt max -3.4028234663852886e+38
# ppt min nan
# ppt max nan
# tavg min -3.4028234663852886e+38
# tavg min nan
# interception min nan
# 2014 1 30
# today is 030
# swout swi_2014030.tif
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# -------------------------------
# output monthly is True and output yearly is False
# settings {'name_fmt': 'med{}.250_m_NDVI.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NDVI_filled/med2003_2017', 'climatology': True}
# settings {'name_fmt': 'pet{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/', 'climatology': True}
# settings {'name_fmt': 'prec_{}.tif', 'dt_fmt': 'YYYYdoy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico', 'climatology': False, 'na_vals': []}
# settings {'name_fmt': 'tavg_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmin_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmax_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily', 'climatology': True}
# warpfile /vsis3/dev-et-data/NDVI_filled/med2003_2017/med031.250_m_NDVI.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/pet031.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico/2014/prec_2014031.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily/tavg_031.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily/tmin_031.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily/tmax_031.tif
# <class 'rasterio.vrt.WarpedVRT'>
# ppt min -3.4028234663852886e+38
# ppt max -3.4028234663852886e+38
# ppt min nan
# ppt max nan
# tavg min -3.4028234663852886e+38
# tavg min nan
# interception min nan
# 2014 1 31
# today is 031
# swout swi_2014031.tif
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# -------------------------------
# output monthly is False and output yearly is False
# settings {'name_fmt': 'med{}.250_m_NDVI.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NDVI_filled/med2003_2017', 'climatology': True}
# settings {'name_fmt': 'pet{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/', 'climatology': True}
# settings {'name_fmt': 'prec_{}.tif', 'dt_fmt': 'YYYYdoy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico', 'climatology': False, 'na_vals': []}
# settings {'name_fmt': 'tavg_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmin_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmax_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily', 'climatology': True}
# warpfile /vsis3/dev-et-data/NDVI_filled/med2003_2017/med032.250_m_NDVI.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/pet032.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico/2014/prec_2014032.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily/tavg_032.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily/tmin_032.tif
# <class 'rasterio.vrt.WarpedVRT'>
# warpfile /vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily/tmax_032.tif
# <class 'rasterio.vrt.WarpedVRT'>
# ppt min -3.4028234663852886e+38
# ppt max -3.4028234663852886e+38
# ppt min nan
# ppt max nan
# tavg min -3.4028234663852886e+38
# tavg min nan
# interception min nan
# 2014 2 1
# today is 032
# swout swi_2014032.tif
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# (4806, 4807)
# -------------------------------
# output monthly is False and output yearly is False
# settings {'name_fmt': 'med{}.250_m_NDVI.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NDVI_filled/med2003_2017', 'climatology': True}
# settings {'name_fmt': 'pet{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/ETo_mosaic/', 'climatology': True}
# settings {'name_fmt': 'prec_{}.tif', 'dt_fmt': 'YYYYdoy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico', 'climatology': False, 'na_vals': []}
# settings {'name_fmt': 'tavg_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tavg_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmin_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmin_C_daily', 'climatology': True}
# settings {'name_fmt': 'tmax_{}.tif', 'dt_fmt': 'doy', 'dir_loc': '/vsis3/dev-et-data/NA_data_for_cloud/Temperature/tmax_C_daily', 'climatology': True}
# warpfile /vsis3/dev-et-data/NDVI_filled/med2003_2017/med033.250_m_NDVI.tif

# %%
# with rasterio.open(ps3, 'r') as src:
    
#     plt.imshow(src.read(1), cmap='pink')
#     plt.show()
