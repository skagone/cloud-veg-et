# %% [markdown]
# ## File download to local drive

# %%
# %env drop=/home/ubuntu/000dropbox
#%env drop=opt/cloud-veg-et/model_outputs

import boto3
from boto3 import client
def bo_get_bucket_list(bucket_name, prefix):

    s3_conn   = client('s3')  # type: BaseClient  ## again assumes boto.cfg setup, assume AWS S3
    s3_result =  s3_conn.list_objects_v2(Bucket=bucket_name, Prefix=prefix, Delimiter = "/")

    if 'Contents' not in s3_result:
        #print(s3_result)
        return []

    file_list = []
    for key in s3_result['Contents']:
        file_list.append(key['Key'])
    print(f"List count = {len(file_list)}")

    while s3_result['IsTruncated']:
        continuation_key = s3_result['NextContinuationToken']
        s3_result = s3_conn.list_objects_v2(Bucket=bucket_name, Prefix=prefix, Delimiter="/", ContinuationToken=continuation_key)
        for key in s3_result['Contents']:
            file_list.append(key['Key'])
        print(f"List count = {len(file_list)}")
    return file_list

buck = 'ga-et-data'
pre = 'gabe_outputs/model_outputs/'

file_list = bo_get_bucket_list(buck, pre)

print(file_list[1])
# Out:
# env: drop=/home/ubuntu/000dropbox
# List count = 1000
# List count = 2000
# List count = 3000
# List count = 4000
# List count = 5000
# List count = 6000
# List count = 7000
# List count = 8000
# List count = 9000
# List count = 10000
# List count = 11000
# List count = 12000
# List count = 12009
# gabe_outputs/model_outputs/dd_201310.tif

# %%
#Filter list for needed files
filter='dd_20140'
filtered_list = []
for file in file_list:
    if (filter in file):
        # print(file)
        filtered_list.append(file)

# "copy" all needed file names in txt file        
target = open('export_files.txt', 'w')
for file in filtered_list:
    print(file)
    target.write(file+'\n')
target.close()
# Out:
# gabe_outputs/model_outputs/dd_2014001.tif
# gabe_outputs/model_outputs/dd_2014002.tif
# gabe_outputs/model_outputs/dd_2014003.tif
# gabe_outputs/model_outputs/dd_2014004.tif
# gabe_outputs/model_outputs/dd_2014005.tif
# gabe_outputs/model_outputs/dd_2014006.tif
# gabe_outputs/model_outputs/dd_2014007.tif
# gabe_outputs/model_outputs/dd_2014008.tif
# gabe_outputs/model_outputs/dd_2014009.tif
# gabe_outputs/model_outputs/dd_201401.tif
# gabe_outputs/model_outputs/dd_2014010.tif
# gabe_outputs/model_outputs/dd_2014011.tif
# gabe_outputs/model_outputs/dd_2014012.tif
# gabe_outputs/model_outputs/dd_2014013.tif
# gabe_outputs/model_outputs/dd_2014014.tif
# gabe_outputs/model_outputs/dd_2014015.tif
# gabe_outputs/model_outputs/dd_2014016.tif
# gabe_outputs/model_outputs/dd_2014017.tif
# gabe_outputs/model_outputs/dd_2014018.tif
# gabe_outputs/model_outputs/dd_2014019.tif
# gabe_outputs/model_outputs/dd_201402.tif
# gabe_outputs/model_outputs/dd_2014020.tif
# gabe_outputs/model_outputs/dd_2014021.tif
# gabe_outputs/model_outputs/dd_2014022.tif
# gabe_outputs/model_outputs/dd_2014023.tif
# gabe_outputs/model_outputs/dd_2014024.tif
# gabe_outputs/model_outputs/dd_2014025.tif
# gabe_outputs/model_outputs/dd_2014026.tif
# gabe_outputs/model_outputs/dd_2014027.tif
# gabe_outputs/model_outputs/dd_2014028.tif
# gabe_outputs/model_outputs/dd_2014029.tif
# gabe_outputs/model_outputs/dd_201403.tif
# gabe_outputs/model_outputs/dd_2014030.tif
# gabe_outputs/model_outputs/dd_2014031.tif
# gabe_outputs/model_outputs/dd_2014032.tif
# gabe_outputs/model_outputs/dd_2014093.tif
# gabe_outputs/model_outputs/dd_2014094.tif
# gabe_outputs/model_outputs/dd_2014095.tif
# gabe_outputs/model_outputs/dd_2014096.tif
# gabe_outputs/model_outputs/dd_2014097.tif
# gabe_outputs/model_outputs/dd_2014098.tif
# gabe_outputs/model_outputs/dd_2014099.tif

# %%
! cat -n export_files.txt
# Out:
#      1	gabe_outputs/model_outputs/dd_2014001.tif
#      2	gabe_outputs/model_outputs/dd_2014002.tif
#      3	gabe_outputs/model_outputs/dd_2014003.tif
#      4	gabe_outputs/model_outputs/dd_2014004.tif
#      5	gabe_outputs/model_outputs/dd_2014005.tif
#      6	gabe_outputs/model_outputs/dd_2014006.tif
#      7	gabe_outputs/model_outputs/dd_2014007.tif
#      8	gabe_outputs/model_outputs/dd_2014008.tif
#      9	gabe_outputs/model_outputs/dd_2014009.tif
#     10	gabe_outputs/model_outputs/dd_201401.tif
#     11	gabe_outputs/model_outputs/dd_2014010.tif
#     12	gabe_outputs/model_outputs/dd_2014011.tif
#     13	gabe_outputs/model_outputs/dd_2014012.tif
#     14	gabe_outputs/model_outputs/dd_2014013.tif
#     15	gabe_outputs/model_outputs/dd_2014014.tif
#     16	gabe_outputs/model_outputs/dd_2014015.tif
#     17	gabe_outputs/model_outputs/dd_2014016.tif
#     18	gabe_outputs/model_outputs/dd_2014017.tif
#     19	gabe_outputs/model_outputs/dd_2014018.tif
#     20	gabe_outputs/model_outputs/dd_2014019.tif
#     21	gabe_outputs/model_outputs/dd_201402.tif
#     22	gabe_outputs/model_outputs/dd_2014020.tif
#     23	gabe_outputs/model_outputs/dd_2014021.tif
#     24	gabe_outputs/model_outputs/dd_2014022.tif
#     25	gabe_outputs/model_outputs/dd_2014023.tif
#     26	gabe_outputs/model_outputs/dd_2014024.tif
#     27	gabe_outputs/model_outputs/dd_2014025.tif
#     28	gabe_outputs/model_outputs/dd_2014026.tif
#     29	gabe_outputs/model_outputs/dd_2014027.tif
#     30	gabe_outputs/model_outputs/dd_2014028.tif
#     31	gabe_outputs/model_outputs/dd_2014029.tif
#     32	gabe_outputs/model_outputs/dd_201403.tif
#     33	gabe_outputs/model_outputs/dd_2014030.tif
#     34	gabe_outputs/model_outputs/dd_2014031.tif
#     35	gabe_outputs/model_outputs/dd_2014032.tif
#     36	gabe_outputs/model_outputs/dd_2014033.tif
#     37	gabe_outputs/model_outputs/dd_2014034.tif
#     38	gabe_outputs/model_outputs/dd_2014035.tif
#     39	gabe_outputs/model_outputs/dd_2014036.tif
#     40	gabe_outputs/model_outputs/dd_2014037.tif
#     41	gabe_outputs/model_outputs/dd_2014038.tif
#     42	gabe_outputs/model_outputs/dd_2014039.tif
#     43	gabe_outputs/model_outputs/dd_201404.tif
#     44	gabe_outputs/model_outputs/dd_2014040.tif
#     45	gabe_outputs/model_outputs/dd_2014041.tif
#     46	gabe_outputs/model_outputs/dd_2014042.tif
#     47	gabe_outputs/model_outputs/dd_2014043.tif
#     48	gabe_outputs/model_outputs/dd_2014044.tif
#     49	gabe_outputs/model_outputs/dd_2014045.tif
#     50	gabe_outputs/model_outputs/dd_2014046.tif
#     51	gabe_outputs/model_outputs/dd_2014047.tif
#     52	gabe_outputs/model_outputs/dd_2014048.tif
#     53	gabe_outputs/model_outputs/dd_2014049.tif
#     54	gabe_outputs/model_outputs/dd_201405.tif
#     55	gabe_outputs/model_outputs/dd_2014050.tif
#     56	gabe_outputs/model_outputs/dd_2014051.tif
#     57	gabe_outputs/model_outputs/dd_2014052.tif
#     58	gabe_outputs/model_outputs/dd_2014053.tif
#     59	gabe_outputs/model_outputs/dd_2014054.tif
#     60	gabe_outputs/model_outputs/dd_2014055.tif
#     61	gabe_outputs/model_outputs/dd_2014056.tif
#     62	gabe_outputs/model_outputs/dd_2014057.tif
#     63	gabe_outputs/model_outputs/dd_2014058.tif
#     64	gabe_outputs/model_outputs/dd_2014059.tif
#     65	gabe_outputs/model_outputs/dd_201406.tif
#     66	gabe_outputs/model_outputs/dd_2014060.tif
#     67	gabe_outputs/model_outputs/dd_2014061.tif
#     68	gabe_outputs/model_outputs/dd_2014062.tif
#     69	gabe_outputs/model_outputs/dd_2014063.tif
#     70	gabe_outputs/model_outputs/dd_2014064.tif
#     71	gabe_outputs/model_outputs/dd_2014065.tif
#     72	gabe_outputs/model_outputs/dd_2014066.tif
#     73	gabe_outputs/model_outputs/dd_2014067.tif
#     74	gabe_outputs/model_outputs/dd_2014068.tif
#     75	gabe_outputs/model_outputs/dd_2014069.tif
#     76	gabe_outputs/model_outputs/dd_201407.tif
#     77	gabe_outputs/model_outputs/dd_2014070.tif
#     78	gabe_outputs/model_outputs/dd_2014071.tif
#     79	gabe_outputs/model_outputs/dd_2014072.tif
#     80	gabe_outputs/model_outputs/dd_2014073.tif
#     81	gabe_outputs/model_outputs/dd_2014074.tif
#     82	gabe_outputs/model_outputs/dd_2014075.tif
#     83	gabe_outputs/model_outputs/dd_2014076.tif
#     84	gabe_outputs/model_outputs/dd_2014077.tif
#     85	gabe_outputs/model_outputs/dd_2014078.tif
#     86	gabe_outputs/model_outputs/dd_2014079.tif
#     87	gabe_outputs/model_outputs/dd_201408.tif
#     88	gabe_outputs/model_outputs/dd_2014080.tif
#     89	gabe_outputs/model_outputs/dd_2014081.tif
#     90	gabe_outputs/model_outputs/dd_2014082.tif
#     91	gabe_outputs/model_outputs/dd_2014083.tif
#     92	gabe_outputs/model_outputs/dd_2014084.tif
#     93	gabe_outputs/model_outputs/dd_2014085.tif
#     94	gabe_outputs/model_outputs/dd_2014086.tif
#     95	gabe_outputs/model_outputs/dd_2014087.tif
#     96	gabe_outputs/model_outputs/dd_2014088.tif
#     97	gabe_outputs/model_outputs/dd_2014089.tif
#     98	gabe_outputs/model_outputs/dd_201409.tif
#     99	gabe_outputs/model_outputs/dd_2014090.tif
#    100	gabe_outputs/model_outputs/dd_2014091.tif
#    101	gabe_outputs/model_outputs/dd_2014092.tif
#    102	gabe_outputs/model_outputs/dd_2014093.tif
#    103	gabe_outputs/model_outputs/dd_2014094.tif
#    104	gabe_outputs/model_outputs/dd_2014095.tif
#    105	gabe_outputs/model_outputs/dd_2014096.tif
#    106	gabe_outputs/model_outputs/dd_2014097.tif
#    107	gabe_outputs/model_outputs/dd_2014098.tif
#    108	gabe_outputs/model_outputs/dd_2014099.tif

# %%
# %%bash
#
# for s3obj in `cat export_files.txt`; do
#     echo $s3obj;
#     aws s3 cp s3://ga-et-data/$s3obj $drop/
# done

# %%
! ls ~ubuntu/000dropbox

# %%
# ! ls -lR $drop
