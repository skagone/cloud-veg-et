# %%
! aws s3 ls s3://dev-et-data/in/DelawareRiverBasin/ETo_Moving_Average_byDOY/1950_1960/
# Out:
# 2020-10-01 06:59:41      35692 ETo_DOY001.tif
# 2020-10-01 06:59:49      35692 ETo_DOY002.tif
# 2020-10-01 06:59:57      35692 ETo_DOY003.tif
# 2020-10-01 07:00:05      35692 ETo_DOY004.tif
# 2020-10-01 07:00:12      35692 ETo_DOY005.tif
# 2020-10-01 07:00:20      35692 ETo_DOY006.tif
# 2020-10-01 07:00:27      35692 ETo_DOY007.tif
# 2020-10-01 07:00:35      35692 ETo_DOY008.tif
# 2020-10-01 07:00:42      35692 ETo_DOY009.tif
# 2020-10-01 07:00:50      35692 ETo_DOY010.tif
# 2020-10-01 07:00:58      35692 ETo_DOY011.tif
# 2020-10-01 07:01:05      35692 ETo_DOY012.tif
# 2020-10-01 07:01:13      35692 ETo_DOY013.tif
# 2020-10-01 07:01:21      35692 ETo_DOY014.tif
# 2020-10-01 07:01:28      35692 ETo_DOY015.tif
# 2020-10-01 07:01:36      35692 ETo_DOY016.tif
# 2020-10-01 07:01:44      35692 ETo_DOY017.tif
# 2020-10-01 07:01:51      35692 ETo_DOY018.tif
# 2020-10-01 07:01:59      35692 ETo_DOY019.tif
# 2020-10-01 07:02:07      35692 ETo_DOY020.tif
# ...

# %%
from vegetLib.s3_stuff import return_s3_list

# %%
working_bucket = 'dev-et-data'
prefix ='in/DelawareRiverBasin/ETo_Moving_Average_byDOY/1950_1960/'
my_list = return_s3_list(working_bucket, prefix)

# %%
import vegetLib

# %%
dir(vegetLib)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  's3_stuff']

# %%
! cat /home/jupyter-kagone/opt/cloud-veg-et/vegetLib/vegetLib/s3_stuff.py
# Out:
# import os
# import boto3
#
# def s3_hello(person_name):
#     print('Hello There Person:', person_name)
#
# def s3_push_delete_local(local_file, bucket, bucket_filepath):
#         s3 = boto3.client('s3')
#         with open(local_file, "rb") as f:
#             if 'vsis3' in bucket:
#                 bucket = bucket.split('/')[-1]
#                 print(bucket, bucket_filepath)
#             s3.upload_fileobj(f, bucket, bucket_filepath)
#         os.remove(local_file)
#
# def return_s3_list(working_bucket, prefix):
#         aws_list = []
#         s3 = boto3.resource('s3')
#         bucket_name = working_bucket
#         bucket = s3.Bucket(bucket_name)
#         for obj in bucket.objects.filter(Prefix=prefix):
#             obj_key = obj.key
#             obj_key = working_bucket + '/' + obj_key
#             aws_list.append((obj_key, obj.size))
#         return aws_list
#
#
# def s3_list_pseudo_subdirs(bucket, prefix_with_slash):
#
#     subfolder_list = []
# ...

# %%
my_list
# Out:
# [('dev-et-data/in/DelawareRiverBasin/ETo_Moving_Average_byDOY/1950_1960/ETo_DOY001.tif',
#   35692),
#  ('dev-et-data/in/DelawareRiverBasin/ETo_Moving_Average_byDOY/1950_1960/ETo_DOY002.tif',
#   35692),
#  ('dev-et-data/in/DelawareRiverBasin/ETo_Moving_Average_byDOY/1950_1960/ETo_DOY003.tif',
#   35692),
#  ('dev-et-data/in/DelawareRiverBasin/ETo_Moving_Average_byDOY/1950_1960/ETo_DOY004.tif',
#   35692),
#  ('dev-et-data/in/DelawareRiverBasin/ETo_Moving_Average_byDOY/1950_1960/ETo_DOY005.tif',
#   35692),
#  ('dev-et-data/in/DelawareRiverBasin/ETo_Moving_Average_byDOY/1950_1960/ETo_DOY006.tif',
#   35692),
#  ('dev-et-data/in/DelawareRiverBasin/ETo_Moving_Average_byDOY/1950_1960/ETo_DOY007.tif',
#   35692),
#  ('dev-et-data/in/DelawareRiverBasin/ETo_Moving_Average_byDOY/1950_1960/ETo_DOY008.tif',
#   35692),
#  ('dev-et-data/in/DelawareRiverBasin/ETo_Moving_Average_byDOY/1950_1960/ETo_DOY009.tif',
#   35692),
# ...

# %%
import rasterio
for tif,sz in my_list:
    ntif= 's3://' + tif
    with rasterio.open(ntif) as src:
        print(src.crs)
# Out:
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# ...

# %%
working_bucket = 'dev-et-data'
prefix ='in/DelawareRiverBasin/PPT/1950/'
my_list = return_s3_list(working_bucket, prefix)
for tif,sz in my_list:
    ntif= 's3://' + tif
    with rasterio.open(ntif) as src:
        print(src.crs)
# Out:
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# ...

# %%
working_bucket = 'dev-et-data'
prefix ='in/DelawareRiverBasin/Temp/Tasavg/1950/'
my_list = return_s3_list(working_bucket, prefix)

# %%
my_list
# Out:
# [('dev-et-data/in/DelawareRiverBasin/Temp/Tasavg/1950/Tasavg_1950001.tif',
#   35692),
#  ('dev-et-data/in/DelawareRiverBasin/Temp/Tasavg/1950/Tasavg_1950002.tif',
#   35692),
#  ('dev-et-data/in/DelawareRiverBasin/Temp/Tasavg/1950/Tasavg_1950003.tif',
#   35692),
#  ('dev-et-data/in/DelawareRiverBasin/Temp/Tasavg/1950/Tasavg_1950004.tif',
#   35692),
#  ('dev-et-data/in/DelawareRiverBasin/Temp/Tasavg/1950/Tasavg_1950005.tif',
#   35692),
#  ('dev-et-data/in/DelawareRiverBasin/Temp/Tasavg/1950/Tasavg_1950006.tif',
#   35692),
#  ('dev-et-data/in/DelawareRiverBasin/Temp/Tasavg/1950/Tasavg_1950007.tif',
#   35692),
#  ('dev-et-data/in/DelawareRiverBasin/Temp/Tasavg/1950/Tasavg_1950008.tif',
#   35692),
#  ('dev-et-data/in/DelawareRiverBasin/Temp/Tasavg/1950/Tasavg_1950009.tif',
#   35692),
#  ('dev-et-data/in/DelawareRiverBasin/Temp/Tasavg/1950/Tasavg_1950010.tif',
#   35692),
#  ('dev-et-data/in/DelawareRiverBasin/Temp/Tasavg/1950/Tasavg_1950011.tif',
#   35692),
# ...

# %%
! rio info /vsis3/dev-et-data/in/DelawareRiverBasin/Temp/Tasavg/1950/Tasmax_1950275.tif
# Out:
# Traceback (most recent call last):
#   File "rasterio/_base.pyx", line 216, in rasterio._base.DatasetBase.__init__
#   File "rasterio/_shim.pyx", line 67, in rasterio._shim.open_dataset
#   File "rasterio/_err.pyx", line 205, in rasterio._err.exc_wrap_pointer
# rasterio._err.CPLE_OpenFailedError: '/vsis3/dev-et-data/in/DelawareRiverBasin/Temp/Tasavg/1950/Tasmax_1950275.tif' does not exist in the file system, and is not recognized as a supported dataset name.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/tljh/user/bin/rio", line 10, in <module>
#     sys.exit(main_group())
#   File "/opt/tljh/user/lib/python3.7/site-packages/click/core.py", line 829, in __call__
#     return self.main(*args, **kwargs)
#   File "/opt/tljh/user/lib/python3.7/site-packages/click/core.py", line 782, in main
#     rv = self.invoke(ctx)
#   File "/opt/tljh/user/lib/python3.7/site-packages/click/core.py", line 1259, in invoke
# ...

# %%
working_bucket = 'dev-et-data'
prefix ='in/DelawareRiverBasin/PPT/1950/'
my_list = return_s3_list(working_bucket, prefix)
for tif,sz in my_list:
    ntif= 's3://' + tif
    with rasterio.open(ntif) as src:
        print(src.crs)
# Out:
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:4326
# ...
